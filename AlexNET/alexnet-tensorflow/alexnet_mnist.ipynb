# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, layers, models, losses
# Out:
# 2024-05-03 17:51:04.364568: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-03 17:51:04.364617: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-03 17:51:04.365728: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-03 17:51:04.374422: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-03 17:51:04.946169: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
(x_train,y_train),(x_test,y_test) = datasets.mnist.load_data()
x_train = tf.pad(x_train, [[0, 0], [2,2], [2,2]])/255
x_test = tf.pad(x_test, [[0, 0], [2,2], [2,2]])/255
x_train = tf.expand_dims(x_train, axis=3, name=None)
x_test = tf.expand_dims(x_test, axis=3, name=None)
x_train = tf.repeat(x_train, 3, axis=3)
x_test = tf.repeat(x_test, 3, axis=3)
x_val = x_train[-2000:,:,:,:]
y_val = y_train[-2000:]
x_train = x_train[:-2000,:,:,:]
y_train = y_train[:-2000]
# Out:
# 2024-05-03 17:51:21.235427: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-03 17:51:21.265531: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-03 17:51:21.265566: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-03 17:51:21.268713: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-03 17:51:21.268778: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-03 17:51:21.268790: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-03 17:51:22.561939: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-03 17:51:22.562022: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-03 17:51:22.562029: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-05-03 17:51:22.562064: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-03 17:51:22.562101: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13515 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape, x_val.shape, y_val.shape
# Out:
# (TensorShape([58000, 32, 32, 3]),
#  (58000,),
#  TensorShape([10000, 32, 32, 3]),
#  (10000,),
#  TensorShape([2000, 32, 32, 3]),
#  (2000,))

# %%
model = models.Sequential()
model.add(layers.experimental.preprocessing.Resizing(224, 224, interpolation="bilinear", input_shape=x_train.shape[1:]))
model.add(layers.Conv2D(96, 11, strides=4, padding='same'))
model.add(layers.Lambda(tf.nn.local_response_normalization))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(3, strides=2))
model.add(layers.Conv2D(256, 5, strides=4, padding='same'))
model.add(layers.Lambda(tf.nn.local_response_normalization))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(3, strides=2))
model.add(layers.Conv2D(384, 3, strides=4, padding='same'))
model.add(layers.Activation('relu'))
model.add(layers.Conv2D(384, 3, strides=4, padding='same'))
model.add(layers.Activation('relu'))
model.add(layers.Conv2D(256, 3, strides=4, padding='same'))
model.add(layers.Activation('relu'))
model.add(layers.Flatten())
model.add(layers.Dense(4096, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4096, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resizing (Resizing)         (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 56, 56, 96)        34944
#
#  lambda (Lambda)             (None, 56, 56, 96)        0
#
#  activation (Activation)     (None, 56, 56, 96)        0
#
#  max_pooling2d (MaxPooling2  (None, 27, 27, 96)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 256)         614656
#
#  lambda_1 (Lambda)           (None, 7, 7, 256)         0
#
#  activation_1 (Activation)   (None, 7, 7, 256)         0
#
#  max_pooling2d_1 (MaxPoolin  (None, 3, 3, 256)         0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 1, 1, 384)         885120
#
#  activation_2 (Activation)   (None, 1, 1, 384)         0
#
#  conv2d_3 (Conv2D)           (None, 1, 1, 384)         1327488
#
#  activation_3 (Activation)   (None, 1, 1, 384)         0
#
#  conv2d_4 (Conv2D)           (None, 1, 1, 256)         884992
#
#  activation_4 (Activation)   (None, 1, 1, 256)         0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 10)                40970
#
# =================================================================
# Total params: 21622154 (82.48 MB)
# Trainable params: 21622154 (82.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss=losses.sparse_categorical_crossentropy, metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=64, epochs=40, validation_data=(x_val, y_val))
# Out:
# Epoch 1/40
# 2024-05-03 17:52:52.819257: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-05-03 17:52:54.483856: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-03 17:52:55.265030: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-03 17:52:55.912810: I external/local_xla/xla/service/service.cc:168] XLA service 0x7efec837f9e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-03 17:52:55.912847: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Ti, Compute Capability 8.9
# 2024-05-03 17:52:55.924194: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714740776.005147    4587 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 907/907 [==============================] - 40s 34ms/step - loss: 0.5348 - accuracy: 0.8061 - val_loss: 0.0729 - val_accuracy: 0.9825
# Epoch 2/40
# 907/907 [==============================] - 30s 33ms/step - loss: 0.0996 - accuracy: 0.9735 - val_loss: 0.0446 - val_accuracy: 0.9930
# Epoch 3/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0752 - accuracy: 0.9808 - val_loss: 0.0429 - val_accuracy: 0.9910
# Epoch 4/40
# 907/907 [==============================] - 30s 33ms/step - loss: 0.0609 - accuracy: 0.9848 - val_loss: 0.0700 - val_accuracy: 0.9870
# Epoch 5/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0499 - accuracy: 0.9875 - val_loss: 0.0440 - val_accuracy: 0.9920
# Epoch 6/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0459 - accuracy: 0.9886 - val_loss: 0.0532 - val_accuracy: 0.9870
# Epoch 7/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0379 - accuracy: 0.9903 - val_loss: 0.0387 - val_accuracy: 0.9935
# Epoch 8/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0355 - accuracy: 0.9914 - val_loss: 0.0436 - val_accuracy: 0.9920
# Epoch 9/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0290 - accuracy: 0.9926 - val_loss: 0.0644 - val_accuracy: 0.9900
# Epoch 10/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0277 - accuracy: 0.9931 - val_loss: 0.0876 - val_accuracy: 0.9900
# Epoch 11/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0236 - accuracy: 0.9942 - val_loss: 0.0602 - val_accuracy: 0.9925
# Epoch 12/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0239 - accuracy: 0.9943 - val_loss: 0.0858 - val_accuracy: 0.9850
# Epoch 13/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0242 - accuracy: 0.9944 - val_loss: 0.0675 - val_accuracy: 0.9910
# Epoch 14/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0186 - accuracy: 0.9957 - val_loss: 0.0566 - val_accuracy: 0.9925
# Epoch 15/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0210 - accuracy: 0.9950 - val_loss: 0.0451 - val_accuracy: 0.9935
# Epoch 16/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0168 - accuracy: 0.9957 - val_loss: 0.0532 - val_accuracy: 0.9930
# Epoch 17/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0194 - accuracy: 0.9959 - val_loss: 0.1200 - val_accuracy: 0.9885
# Epoch 18/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0166 - accuracy: 0.9959 - val_loss: 0.0857 - val_accuracy: 0.9935
# Epoch 19/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0195 - accuracy: 0.9956 - val_loss: 0.0743 - val_accuracy: 0.9950
# Epoch 20/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0169 - accuracy: 0.9964 - val_loss: 0.0583 - val_accuracy: 0.9920
# Epoch 21/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0103 - accuracy: 0.9976 - val_loss: 0.0664 - val_accuracy: 0.9915
# Epoch 22/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0153 - accuracy: 0.9964 - val_loss: 0.1242 - val_accuracy: 0.9925
# Epoch 23/40
# 907/907 [==============================] - 30s 33ms/step - loss: 0.0170 - accuracy: 0.9965 - val_loss: 0.0905 - val_accuracy: 0.9895
# Epoch 24/40
# 907/907 [==============================] - 30s 33ms/step - loss: 0.0117 - accuracy: 0.9975 - val_loss: 0.0580 - val_accuracy: 0.9915
# Epoch 25/40
# 907/907 [==============================] - 30s 33ms/step - loss: 0.0128 - accuracy: 0.9973 - val_loss: 0.0761 - val_accuracy: 0.9930
# Epoch 26/40
# 907/907 [==============================] - 30s 33ms/step - loss: 0.0133 - accuracy: 0.9973 - val_loss: 0.1110 - val_accuracy: 0.9925
# Epoch 27/40
# 907/907 [==============================] - 30s 33ms/step - loss: 0.0141 - accuracy: 0.9973 - val_loss: 0.0626 - val_accuracy: 0.9915
# Epoch 28/40
# 907/907 [==============================] - 30s 33ms/step - loss: 0.0142 - accuracy: 0.9972 - val_loss: 0.0533 - val_accuracy: 0.9960
# Epoch 29/40
# 907/907 [==============================] - 30s 33ms/step - loss: 0.0099 - accuracy: 0.9977 - val_loss: 0.0674 - val_accuracy: 0.9935
# Epoch 30/40
# 907/907 [==============================] - 30s 33ms/step - loss: 0.0092 - accuracy: 0.9980 - val_loss: 0.0786 - val_accuracy: 0.9940
# Epoch 31/40
# 907/907 [==============================] - 29s 32ms/step - loss: 0.0110 - accuracy: 0.9978 - val_loss: 0.0672 - val_accuracy: 0.9955
# Epoch 32/40
# 907/907 [==============================] - 28s 31ms/step - loss: 0.0126 - accuracy: 0.9975 - val_loss: 0.0501 - val_accuracy: 0.9945
# Epoch 33/40
# 907/907 [==============================] - 28s 31ms/step - loss: 0.0169 - accuracy: 0.9968 - val_loss: 0.0856 - val_accuracy: 0.9930
# Epoch 34/40
# 907/907 [==============================] - 28s 31ms/step - loss: 0.0064 - accuracy: 0.9988 - val_loss: 0.1309 - val_accuracy: 0.9915
# Epoch 35/40
# 907/907 [==============================] - 28s 31ms/step - loss: 0.0120 - accuracy: 0.9978 - val_loss: 0.0718 - val_accuracy: 0.9925
# Epoch 36/40
# 907/907 [==============================] - 28s 31ms/step - loss: 0.0139 - accuracy: 0.9973 - val_loss: 0.1445 - val_accuracy: 0.9905
# Epoch 37/40
# 907/907 [==============================] - 28s 31ms/step - loss: 0.0127 - accuracy: 0.9976 - val_loss: 0.1349 - val_accuracy: 0.9925
# Epoch 38/40
# 907/907 [==============================] - 28s 31ms/step - loss: 0.0081 - accuracy: 0.9987 - val_loss: 0.1208 - val_accuracy: 0.9900
# Epoch 39/40
# 907/907 [==============================] - 28s 31ms/step - loss: 0.0074 - accuracy: 0.9984 - val_loss: 0.0999 - val_accuracy: 0.9925
# Epoch 40/40
# 907/907 [==============================] - 28s 31ms/step - loss: 0.0062 - accuracy: 0.9991 - val_loss: 0.0996 - val_accuracy: 0.9925

# %%
fig, axs = plt.subplots(2, 1, figsize=(15,15))
axs[0].plot(history.history['loss'])
axs[0].plot(history.history['val_loss'])
axs[0].title.set_text('Training Loss vs Validation Loss')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Loss')
axs[0].legend(['Train', 'Val'])
axs[1].plot(history.history['accuracy'])
axs[1].plot(history.history['val_accuracy'])
axs[1].title.set_text('Training Accuracy vs Validation Accuracy')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Accuracy')
axs[1].legend(['Train', 'Val'])
